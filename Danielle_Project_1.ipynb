# %%
import pandas as pd
import numpy as np
import random
import scipy.stats as stats
import matplotlib.pyplot as plt

# %%
firearm_df = pd.read_csv("Violence Project Firearm Data.csv")
shooting_df = pd.read_csv("Violence Project Shooting Database.csv")
victim_df = pd.read_csv("Violence Project Victim Data1.csv")
victim_df.iloc[0:1267, 0:13]
# Out:
#      Case # Shooter Last Name Shooter First Name Full Date  \
# 0         1           Whitman            Charles    8/1/66
# 1         1           Whitman            Charles    8/1/66
# 2         1           Whitman            Charles    8/1/66
# 3         1           Whitman            Charles    8/1/66
# 4         1           Whitman            Charles    8/1/66
# ...     ...               ...                ...       ...
# 1262    177            Alissa     Ahmad Al Aliwi   3/22/21
# 1263    177            Alissa     Ahmad Al Aliwi   3/22/21
# 1264    177            Alissa     Ahmad Al Aliwi   3/22/21
# 1265    177            Alissa     Ahmad Al Aliwi   3/22/21
# 1266    177            Alissa     Ahmad Al Aliwi   3/22/21
#
#                    Victim Name   Age  Gender  Race  Knew Shooter  \
# 0     Kathleen "Kathy" Whitman  23.0     1.0   0.0           1.0
# 1             Margaret Whitman  43.0     1.0   0.0           1.0
# 2         Martin "Mark" Gabour  16.0     0.0   2.0           0.0
# 3           Marguerite Lamport  45.0     1.0   0.0           0.0
# 4      Edna Elizabeth Townsley  51.0     1.0   0.0           2.0
# ...                        ...   ...     ...   ...           ...
# 1262        Tralona Bartkowiak  49.0     1.0   0.0           0.0
# 1263          Suzanne Fountain  59.0     1.0   0.0           0.0
# 1264               Teri Leiker  51.0     1.0   0.0           0.0
# 1265             Kevin Mahoney  61.0     0.0   0.0           0.0
# 1266               Lynn Murray  62.0     1.0   0.0           0.0
#
#      If Known, Relationship to Shooter  Relationship to Shooter  \
# 0                                 wife                      2.0
# 1                               mother                      1.0
# 2                                  NaN                      0.0
# 3                                  NaN                      0.0
# 4                   employee on campus                      4.0
# ...                                ...                      ...
# 1262                               NaN                      0.0
# 1263                               NaN                      0.0
# 1264                               NaN                      0.0
# 1265                               NaN                      0.0
# 1266                               NaN                      0.0
#
#       Life Expectancy Years Lost
# 0                72.2       49.2
# 1                48.7        5.7
# 2                65.6       49.6
# 3                48.7        3.7
# 4                48.7          0
# ...               ...        ...
# 1262             74.7       25.7
# 1263             73.1       14.1
# 1264             74.7       23.7
# 1265             66.6        5.6
# 1266             73.1       11.1
#
# [1267 rows x 13 columns]

# %%
# #reindex to pull data


# shooting_df.columns = shooting_df.iloc[0]
# shooting_df = shooting_df.iloc[1:]
# shooting_df.head()
# #shooting_df.droplevel(0, axis="columns")
# Out:
# 1  1    Whitman Charles    8/1/66     Monday   1   8  1966  \
# 2  2      Smith  Robert  11/12/66   Saturday  12  11  1966
# 3  3       Held     Leo  10/23/67     Monday  23  10  1967
# 4  4    Pearson    Eric   3/16/68   Saturday  16   3  1968
# 5  5  Lambright  Donald    4/5/69   Saturday   5   4  1969
# 6  6      White  Joseph   9/23/70  Wednesday  23   9  1970
#
# 1           110 Inner Campus Drive, Austin, TX 78705      Austin  ...  1  3  \
# 2             Rose-Mar College of Beauty in Mesa, AZ        Mesa  ...  0  1
# 3      599 South Highland Street Lockhaven, PA 17745  Lock Haven  ...  1  3
# 4                  11703 Lake Rd, Ironwood, MI 49938    Ironwood  ...  0  0
# 5          Pennsylvania Turnpike near Harrisburg, PA  Harrisburg  ...  0  3
# 6  Building 12 W.A. Harriman Campus Albany, NY 12...      Albany  ...  0  2
#
# 1  7  1  \
# 2  1  1
# 3  2  1
# 4  1  0
# 5  2  0
# 6  1  0
#
# 1 hatchet, hammer, knives, wrench, ropes, water, gasoline, matches, food and camping supplies  \
# 2                                  knife, nylon cord
# 3                                            holster
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
#
# 1  1  0  2  0 NaN
# 2  2  0  1  1 NaN
# 3  1  0  2  0 NaN
# 4  2  0  0  3 NaN
# 5  0  0  2  0 NaN
# 6  0  0  2  0 NaN
#
# [5 rows x 143 columns]

# %%
#Create variables to plot.

# victim_name = victim_df.groupby('Shooter Last Name').mean()
# victim_name

victim_name = victim_df.groupby(['Shooter First Name', 'Shooter Last Name']).mean()
#victim_name

shooter_name = shooting_df.groupby(['Shooter First Name', 'Shooter Last Name']).mean()
#shooter_name

shooter_ages = []

comparison_list = []
shoot_age = shooting_df[['Shooter Last Name','Age']]
vict = victim_df['Age']
dif = 
dif
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/24/ffrwmgdx0p71d3f671p8hl_00000gn/T/ipykernel_1920/2360805314.py in <module>
#      15 shoot_age = shooting_df[['Shooter Last Name','Age']]
#      16 vict = victim_df['Age']
# ---> 17 dif = shoot_age['Age']-vict['Age']
#      18 dif
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py in __getitem__(self, key)
#     940
#     941         elif key_is_scalar:
# --> 942             return self._get_value(key)
#     943
#     944         if is_hashable(key):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1049
#    1050         # Similar to Index.get_value, but we do not fall back to positional
# -> 1051         loc = self.index.get_loc(label)
#    1052         return self.index._get_values_for_loc(self, loc, label)
#    1053
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     386                 except ValueError as err:
#     387                     raise KeyError(key) from err
# --> 388             raise KeyError(key)
#     389         return super().get_loc(key, method=method, tolerance=tolerance)
#     390
#
# KeyError: 'Age'

# %%
for index, row in victim_df.iterrows():
    victim_age = row['Age']
    shooting_first = row['Shooter Last Name']
    shooting_last = row['Shooter First Name']
    shooter_details = shooting_df['Shooter Last Name'] == shooting_first
    last_name = shooting_df['Shooter First Name'] == shooting_last
    x = shooter_details & last_name
    shooter_age = shooting_df[x]['Age']
    shooter_ages += [shooter_age]
    print(abs(float(shooter_age) - float(victim_age))<5)
    comparison = 1 if abs(float(shooter_age) - float(victim_age)) <= 5 else 0
    comparison_list += [comparison]
    
print(knew_shooter)
    
# print(victim_df.shape)
# print(len(shooter_ages))
    
victim_df['Shooter Ages'] = pd.Series(shooter_ages)
victim_df['comparison'] = (victim_df['Age'].sub(victim_df['Shooter Ages'])).apply(lambda x: 1 if abs(x) <= 5 else 0)
victim_df['comparison'] = pd.Series(comparison_list)
print(victim_df.columns)
    
proportions_ztest(130.5, 261, value=count_1)

#type(victim_age)

print(shooter_name['Age'])

print(victim_name.shape)
print(shooter_name.shape)

print(victim_name.head)
print(shooter_name.head)

# victim_name['Age']
# victim_name.loc[victim_name['Shooter Last Name'=='Held']]

#print(victim_age.value_counts())
# Out:
# True
# False
# False
# False
# False
# False
# False
# True
# False
# True
# False
# False
# True
# True
# False
# False
# False
# True
# True
# True
# False
# False
# False
# False
# True
# False
# False
# False
# False
# True
# False
# True
# False
# False
# False
# True
# True
# True
# True
# True
# True
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# True
# True
# True
# True
# True
# True
# True
# True
# False
# True
# False
# False
# False
# True
# True
# False
# True
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# True
# False
# True
# True
# True
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# True
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# True
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# True
# False
# False
# True
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# True
# False
# False
# True
# False
# True
# False
# True
# False
# True
# False
# False
# False
# False
# False
# False
# True
# True
# True
# True
# False
# False
# False
# False
# True
# False
# False
# True
# True
# True
# False
# True
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# True
# True
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# True
# False
# False
# True
# True
# True
# False
# True
# False
# False
# True
# False
# False
# True
# True
# True
# False
# True
# True
# True
# False
# False
# True
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# True
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# True
# True
# False
# True
# False
# False
# False
# False
# False
# False
# True
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# True
# False
# False
# True
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# True
# False
# True
# True
# False
# True
# True
# True
# True
# False
# True
# True
# True
# True
# False
# False
# False
# True
# True
# True
# True
# False
# False
# True
# True
# True
# True
# True
# True
# True
# False
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# False
# True
# True
# True
# True
# True
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# True
# True
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# True
# True
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# True
# True
# False
# True
# False
# False
# False
# False
# False
# True
# True
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# True
# False
# True
# False
# False
# False
# False
# True
# False
# False
# True
# False
# False
# True
# True
# True
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# True
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# True
# True
# False
# False
# True
# False
# True
# True
# False
# False
# True
# False
# False
# False
# True
# False
# False
# False
# True
# True
# False
# False
# False
# True
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# True
# False
# True
# True
# False
# False
# False
# True
# True
# True
# False
# True
# True
# True
# True
# False
# False
# False
# True
# True
# True
# True
# True
# False
# True
# True
# True
# False
# False
# True
# True
# True
# False
# False
# False
# False
# False
# False
# False
# False
# True
# True
# False
# False
# False
# True
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# True
# True
# True
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# True
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# True
# True
# False
# True
# True
# True
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# True
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# True
# False
# False
# False
# True
# True
# True
# True
# False
# True
# True
# False
# False
# True
# True
# False
# True
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# True
# True
# False
# False
# True
# False
# True
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# True
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# True
# False
# False
# False
# True
# False
# True
# False
# False
# False
# False
# False
# True
# False
# True
# False
# False
# False
# True
# False
# True
# False
# False
# False
# False
# False
# False
# False
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/24/ffrwmgdx0p71d3f671p8hl_00000gn/T/ipykernel_1920/1598014056.py in <module>
#      23     shooter_age = shooting_df[x]['Age']
#      24     shooter_ages += [shooter_age]
# ---> 25     print(abs(float(shooter_age) - float(victim_age))<5)
#      26     comparison = 1 if abs(float(shooter_age) - float(victim_age)) <= 5 else 0
#      27     comparison_list += [comparison]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py in wrapper(self)
#     183         if len(self) == 1:
#     184             return converter(self.iloc[0])
# --> 185         raise TypeError(f"cannot convert the series to {converter}")
#     186
#     187     wrapper.__name__ = f"__{converter.__name__}__"
#
# TypeError: cannot convert the series to <class 'float'>

# %%
shooter_age = shooting_df['Age']

print(shooter_age.size)

shooting_df = shooting_df[victim_df['Shooter Last Name'].isin(shooting_df["Shooter Last Name"])]
print(shooting_df.shape)
# Out:
# 351
# (351, 143)
# /var/folders/24/ffrwmgdx0p71d3f671p8hl_00000gn/T/ipykernel_1920/3096471563.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   shooting_df = shooting_df[victim_df['Shooter Last Name'].isin(shooting_df["Shooter Last Name"])]

# %%
#Define variables in the scatter plot
y_variable = victim_name['Age']
x_variable = shooter_name['Age']

victim_name['Age']
x_variable = shooter_name['Age']

# # Give our chart some labels and a tile
plt.title("Victim/Shooter Age Proximity: Averaged")
plt.xlabel("Shooter Age")
plt.ylabel("Average Victim Age")

#plot the findings
#the maximum x value for my the chart will be 182(the number of shooters)

x_limit = 100
x_axis = np.arange(0, x_limit, 1)

#random array of data for the y values
data = [random.random() for value in x_axis]

plt.plot([0,100],[0,100], color = 'blue')

plt.scatter(x_variable, y_variable)
    
#calculate mean squared difference
#((x_variable - y_variable).mul(x_variable - y_variable)).mean()

#np.corrcoef(x_variable, y_variable)[0,1]

# %%
proportions_ztest(130.5, 261, value=count_1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/24/ffrwmgdx0p71d3f671p8hl_00000gn/T/ipykernel_1920/2412686697.py in <module>
# ----> 1 proportions_ztest(130.5, 261, value=count_1)
#
# NameError: name 'proportions_ztest' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import chi2

#x-axis ranges from 0 to 20 with .001 steps
x = np.arange(0, 20, 0.001)

#plot Chi-square distribution with 4 degrees of freedom
plt.plot(x, chi2.pdf(x, df=4))

# %%
#Define variables in the scatter plot
y_variable = row['Age']
x_variable = victim_age

# # Give our chart some labels and a tile
plt.title("Hypothesis Testing")
plt.xlabel("Shooter Age")
plt.ylabel("Individual Age")

#plot the findings
#the maximum x value for my the chart will be 182(the number of shooters)

x_limit = 100
x_axis = np.arange(0, x_limit, 1)

#random array of data for the y values
data = [random.random() for value in x_axis]

plt.plot([0,100],[0,100], color = 'blue')

plt.scatter(x_variable, y_variable)
    
#calculate mean squared difference
((x_variable - y_variable).mul(x_variable - y_variable)).mean()

np.corrcoef(x_variable, y_variable)[0,1]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/24/ffrwmgdx0p71d3f671p8hl_00000gn/T/ipykernel_1920/2427293145.py in <module>
#      22
#      23 #calculate mean squared difference
# ---> 24 ((x_variable - y_variable).mul(x_variable - y_variable)).mean()
#      25
#      26 np.corrcoef(x_variable, y_variable)[0,1]
#
# AttributeError: 'float' object has no attribute 'mul'

# %%
# the degree of freedom for the first null hypothesis is 180-1 = 179
# With a p-value of .05, the confidence level is 1.00-0.05 = .95
critical value = stats.chi2.ppf(q = 0.95, df = 179
# Out:
#   File "/var/folders/24/ffrwmgdx0p71d3f671p8hl_00000gn/T/ipykernel_1920/2072523885.py", line 3
#     critical value = stats.chi2.ppf(q = 0.95, df = 179
#              ^
# SyntaxError: invalid syntax

# %%
# show the critical value
critical_value

# %%
# Run the chi square test with stats.chisquare()

# %%
#Create variables to plot.

# # victim_name = victim_df.groupby('Shooter Last Name').mean()
# # victim_name

# victim_name = victim_df.groupby(['Shooter First Name', 'Shooter Last Name']).mean()
# #victim_name

# shooter_name = shooting_df.groupby(['Shooter First Name', 'Shooter Last Name']).mean()
# #shooter_name

# %%
#Define variables in the scatter plot
# y_variable = victim_df['Knew Shooter']
# x_variable = victim_df['Case #']

# # # Give our chart some labels and a tile
# plt.title("Victim/Shooter Familiarity")
# plt.xlabel("Shooter Name")
# plt.ylabel("Victim Average of Whether Victims/Shooters Met Prior")

# #plot the findings

# x_limit = 180
# x_axis = np.arange(0, x_limit, 1)

# #random array of data for the y values
# data = [random.random() for value in x_axis]

# plt.plot([0,182],[0,2], color = 'green')

# plt.scatter(x_variable, y_variable)
    
# #calculate mean squared difference
# ((x_variable - y_variable).mul(x_variable - y_variable)).mean()

# np.corrcoef(x_variable, y_variable)[0,1]


y_axis = [0, 1, 2]
x_axis = victim_df['Case #']

plt.bar(x_axis, y_axis, color='r', alpha=0.5, align="center")

# Tell matplotlib where we would like to place each of our x axis headers
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, ["Java", "C++", "Python", "Ruby", "Clojure"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/24/ffrwmgdx0p71d3f671p8hl_00000gn/T/ipykernel_1920/3769016378.py in <module>
#      29 x_axis = victim_df['Case #']
#      30
# ---> 31 plt.bar(x_axis, y_axis, color='r', alpha=0.5, align="center")
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2649         x, height, width=0.8, bottom=None, *, align='center',
#    2650         data=None, **kwargs):
# -> 2651     return gca().bar(
#    2652         x, height, width=width, bottom=bottom, align=align,
#    2653         **({"data": data} if data is not None else {}), **kwargs)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1359     def inner(ax, *args, data=None, **kwargs):
#    1360         if data is None:
# -> 1361             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1362
#    1363         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2302                 yerr = self._convert_dx(yerr, y0, y, self.convert_yunits)
#    2303
# -> 2304         x, height, width, y, linewidth, hatch = np.broadcast_arrays(
#    2305             # Make args iterable too.
#    2306             np.atleast_1d(x), height, width, y, linewidth, hatch)
#
# <__array_function__ internals> in broadcast_arrays(*args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/numpy/lib/stride_tricks.py in broadcast_arrays(subok, *args)
#     536     args = [np.array(_m, copy=False, subok=subok) for _m in args]
#     537
# --> 538     shape = _broadcast_shape(*args)
#     539
#     540     if all(array.shape == shape for array in args):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/numpy/lib/stride_tricks.py in _broadcast_shape(*args)
#     418     # use the old-iterator because np.nditer does not handle size 0 arrays
#     419     # consistently
# --> 420     b = np.broadcast(*args[:32])
#     421     # unfortunately, it cannot handle 32 or more arguments directly
#     422     for pos in range(32, len(args), 31):
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape
